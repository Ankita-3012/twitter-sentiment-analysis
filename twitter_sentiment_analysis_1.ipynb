# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankita-3012/twitter-sentiment-analysis/blob/main/twitter_sentiment_analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

base_dir = "/content/twitter-sentiment-analysis"
folders = ["data", "notebooks", "models", "visuals"]
for folder in folders:
  os.makedirs(os.path.join(base_dir, folder), exist_ok=True)

print("Project folders created successfully!")
# Out:
# Project folders created successfully!

# %%
notebook_path = "/content/twittwe-sentiment-analysis/notebooks/twitter-sentiment-analysis-1.ipynb"
